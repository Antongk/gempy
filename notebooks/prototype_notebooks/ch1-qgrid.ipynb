# %% [markdown]
# # Chapter 1: GemPy Basic
#
# In this first example, we will show how to construct a first basic model and the main objects and functions. First we import gempy:

# %%
# These two lines are necessary only if gempy is not installed
import sys, os
sys.path.append("../..")

# Importing gempy
import gempy as gp

# Embedding matplotlib figures into the notebooks
# %matplotlib inline

# Aux imports
import numpy as np
import pandas as pn
# Out:
# ../../gempy/plotting/visualization.py:36: UserWarning: Steno 3D package is not installed. No 3D online visualization available.
#   warnings.warn('Steno 3D package is not installed. No 3D online visualization available.')
# ../../gempy/data_management.py:34: UserWarning: qgrid package is not installed. No interactive dataframes available.
#   warnings.warn('qgrid package is not installed. No interactive dataframes available.')
# ../../gempy/posterior_analysis.py:24: UserWarning: pymc (v2) package is not installed. No support for stochastic simulation posterior analysis.
#   warnings.warn("pymc (v2) package is not installed. No support for stochastic simulation posterior analysis.")
# ../../gempy/posterior_analysis.py:28: UserWarning: pymc (v3) package is not installed. No support for stochastic simulation posterior analysis.
#   warnings.warn("pymc (v3) package is not installed. No support for stochastic simulation posterior analysis.")
# ../../gempy/posterior_analysis.py:35: UserWarning: tqdm package not installed. No support for dynamic progress bars.
#   warnings.warn("tqdm package not installed. No support for dynamic progress bars.")

# %%
# Importing the data from csv files and settign extent and resolution
geo_data = gp.create_data([0,2000,0,2000,-2000,0],[ 20,20,20],
                         path_o = os.pardir+"/input_data/FabLessPoints_Foliations.csv",
                         path_i = os.pardir+"/input_data/FabLessPoints_Points.csv")

# %%
gp.set_series(geo_data, {"fault":'MainFault', 
                      "Rest": ('SecondaryReservoir','Seal', 'Reservoir', 'Overlying'), 
                               },
                       order_series = ["fault", 'Rest'],
                       order_formations=['MainFault', 
                                         'SecondaryReservoir', 'Seal','Reservoir', 'Overlying',
                                         ])

# %%
formations_series = geo_data.faults.index[~geo_data.faults['isFault']]

# %%
formations_series
# Out:
# Index(['Rest'], dtype='object')

# %%
geo_temp = gp.select_series(geo_data, formations_series)

# %%
pile = gp.get_sequential_pile(geo_data, only_formations=True, path='pile.png')

# %%
pile.figure

# %%
handles,labels = pile.figure.axes[0].get_legend_handles_labels()
handles,labels = ax.get_legend_handles_labels()
fig, ax = plt.subplots()
ax.xaxis.set_visible(False)
ax.yaxis.set_visible(False)
for v in ax.spines.values():
    v.set_visible(False)
fig.savefig('test.png', bbox_inches= 'tight', transparent=True)

# %%
geo_data.series.columns.size
# Out:
# 2

# %%
handles
# Out:
# [<matplotlib.patches.Rectangle at 0x1c1eba9518>,
#  <matplotlib.patches.Rectangle at 0x102c984a8>,
#  <matplotlib.patches.Rectangle at 0x1c1e9c2a90>,
#  <matplotlib.patches.Rectangle at 0x1c1e9c2b38>,
#  <matplotlib.patches.Rectangle at 0x1c1e9c20f0>,
#  <matplotlib.patches.Rectangle at 0x1c1e9b7ef0>]

# %%
labels
# Out:
# ['Rest', 'SecondaryReservoir', 'Seal', 'Reservoir', 'Overlying', 'basement']

# %%
ax.legend(handles, labels)

# %%
plt.figlegend(['foo', 'fooo'])

# %%
pile.figure.savefig('pile.png', bbox_inches =]]))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-9edafef9764e> in <module>()
# ----> 1 pile.figure.savefig('pile.png', bbox_inches = np.array([[0,2],[0,2]]))
#
# /anaconda3/lib/python3.6/site-packages/matplotlib/figure.py in savefig(self, fname, **kwargs)
#    1832             self.set_frameon(frameon)
#    1833
# -> 1834         self.canvas.print_figure(fname, **kwargs)
#    1835
#    1836         if frameon:
#
# /anaconda3/lib/python3.6/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, **kwargs)
#    2194             bbox_inches = rcParams['savefig.bbox']
#    2195
# -> 2196         if bbox_inches:
#    2197             # call adjust_bbox to save only the given area
#    2198             if bbox_inches == "tight":
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %%
import matplotlib.pyplot as plt
plt.show(pile.figure.legend())

# %%
plt.legend(pile.figure)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-7501519c85ee> in <module>()
# ----> 1 plt.legend(pile.figure)
#
# /anaconda3/lib/python3.6/site-packages/matplotlib/pyplot.py in legend(*args, **kwargs)
#    3742 @docstring.copy_dedent(Axes.legend)
#    3743 def legend(*args, **kwargs):
# -> 3744     ret = gca().legend(*args, **kwargs)
#    3745     return ret
#    3746
#
# /anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py in legend(self, *args, **kwargs)
#     495                 [self],
#     496                 *args,
# --> 497                 **kwargs)
#     498         if len(extra_args):
#     499             raise TypeError('legend only accepts two non-keyword arguments')
#
# /anaconda3/lib/python3.6/site-packages/matplotlib/legend.py in _parse_legend_args(axs, *args, **kwargs)
#    1382         # Get as many handles as there are labels.
#    1383         handles = [handle for handle, label
# -> 1384                    in zip(_get_legend_handles(axs, handlers), labels)]
#    1385
#    1386     # Two arguments:
#
# TypeError: zip argument #2 must support iteration
